# %%
from os.path import isfile, join
import matplotlib.pyplot as plt
from os import listdir
import pandas as pd
import numpy as np
import os

# %%
files = [f for f in listdir(".") if isfile(join(".", f))]
files.remove("visualize_csv.ipynb")
files.remove('csvconvert.py')
files
# Out:
# ['mao.R.csv',
#  'pe.L.csv',
#  'canela.R.csv',
#  'cabeca.csv',
#  'pelvis.csv',
#  'clavicula.L.csv',
#  'femur.R.csv',
#  'pontape.L.csv',
#  'antebraco.L.csv',
#  'braco.R.csv',
#  'clavicula.R.csv',
#  'canela.L.csv',
#  'torax.csv',
#  'antebraco.R.csv',
#  'respiracao.csv',
#  'femur.L.csv',
#  'pe.R.csv',
#  'abdomen.csv',
#  'braco.L.csv',
#  'pontape.R.csv',
#  'pescoco.csv']

# %%
part = "braco.R" 
data = pd.read_csv("{}.csv".format(part))
data
# Out:
#       LinAccel: x         y         z  AngVel: x  y.1  z.1  Magnetometer: x  \
# 0    9.952254e-06  0.006821  0.001165        0.0  0.0  0.0                0
# 1   -1.050958e-06 -0.000720 -0.000123        0.0  0.0  0.0                0
# 2    3.641796e-07  0.000250  0.000043        0.0  0.0  0.0                0
# 3    2.217497e-07  0.000152  0.000026        0.0  0.0  0.0                0
# 4    9.825255e-06  0.006734  0.001150        0.0  0.0  0.0                0
# ..            ...       ...       ...        ...  ...  ...              ...
# 415  6.054428e-05 -0.000031  0.000031        0.0  0.0  0.0                0
# 416 -9.826407e-04  0.000511 -0.000499        0.0  0.0  0.0                0
# 417 -2.744238e-03  0.001428 -0.001393        0.0  0.0  0.0                0
# 418  1.806051e-03 -0.000940  0.000917        0.0  0.0  0.0                0
# 419  1.000022e-03 -0.000520  0.000508        0.0  0.0  0.0                0
#
#      y.2  z.2       time     name
# 0      0    0   0.020000  braco.R
# 1      0    0   0.353333  braco.R
# 2      0    0   0.506895  braco.R
# 3      0    0   0.628720  braco.R
# 4      0    0   0.662872  braco.R
# ..   ...  ...        ...      ...
# 415    0    0  26.954340  braco.R
# 416    0    0  27.005450  braco.R
# 417    0    0  27.040880  braco.R
# 418    0    0  27.090130  braco.R
# 419    0    0  27.162060  braco.R
#
# [420 rows x 11 columns]

# %%
def drop(data, sort, percent=0.06, by_axis=False):
    to_drop = []
    i = 0
    while i < len(sort) * percent:
        to_drop.append(sort[i][0])
        i += 1
    
    return data.drop(data.index[to_drop])
#     return data

def filter_data(data, key, percent=0.01, by_axis=False):
#     return data
    if by_axis:
        y = data.iloc[:,key]
    else:
        y = data[key]
        
    x = range(len(y))
    xy = list(zip(x, y))
    
    #should sort by abs of derivative
    sort = sorted(xy, key=lambda tup: tup[1], reverse=True)
    data = drop(data, sort, percent=percent)
    data.reset_index(drop=True)
    if by_axis:
        y = data.iloc[:,key]
    else:
        y = data[key]
        
    x = range(len(y))
    xy = list(zip(x, y))
    sort = sorted(xy, key=lambda tup: tup[1], reverse=True)
    
    if not by_axis:
        key = data.columns.get_loc(key)
    
#     i = 0
#     while i < len(y) * percent:
#         row = sort[i][0]
#         if (row == len(xy) - 1):
#             data.iloc[row, key] = data.iloc[row - 1, key]
#         elif (row == 0):
#             data.iloc[row, key] = data.iloc[row + 1, key]
#         else:    
#             data.iloc[row, key] = 0.5 * (data.iloc[row - 1, key] + data.iloc[row + 1, key])
#         i += 1

    for row in range(len(sort)):
        if row == 0:
            continue
        
        data.iloc[row, key] = (1 - percent) * data.iloc[row, key] + percent * data.iloc[row - 1, key] 
        
    return data

# %%
def integrate(xy):
    integrals = []
    integrals.append(xy[0][1] * xy[0][0])
    i = -1
    for element in xy:
        if i == -1:
            i += 1
            continue
        
        deltatime = element[0] - xy[i][0]
        integrals.append(element[1] * (deltatime) + integrals[i])
        i += 1
    return integrals

# %%
data = filter_data(data, "y.1", percent=0.01)

# %%
zipped = list(zip(data["time"], data["y.1"]))

plt.plot(data["time"], integrate(zipped), 'r')
plt.title("{} angle".format(part))
plt.show()

# %%
data.plot(kind="line", x="time", y="y.1", color="red")
plt.title("{} angular velocity".format(part))
plt.show()

# %%
for file in files:
    df = pd.read_csv(file)
    for axis in range(6):
        df = filter_data(df, axis, by_axis=True)
    df.to_csv(path_or_buf="./final_csv/{}".format(file), index=False)
    print(df)
    df.plot(kind="scatter", x="time", y="y.1")
    plt.title(file)
    plt.show()
# Out:
#      LinAccel: x         y             z      AngVel: x            y.1  \
# 0      -0.001299  0.004267  1.149825e-03   0.000000e+00   0.000000e+00
# 1       0.000123 -0.000403 -1.087090e-04   0.000000e+00   0.000000e+00
# 2      -0.000046  0.000151  4.056733e-05   0.000000e+00   0.000000e+00
# 3      -0.000029  0.000096  2.576914e-05   0.000000e+00   0.000000e+00
# 4      -0.001270  0.004171  1.124058e-03   0.000000e+00   0.000000e+00
# ..           ...       ...           ...            ...            ...
# 415     0.000071 -0.000009  4.307009e-07 -2.290512e-115 -1.636231e-115
# 416    -0.000991  0.000124 -6.026749e-06 -2.290512e-117 -1.636231e-117
# 417    -0.002780  0.000346 -1.690331e-05 -2.290512e-119 -1.636231e-119
# 418     0.001795 -0.000224  1.091579e-05 -2.290512e-121 -1.636231e-121
# 419     0.001028 -0.000128  6.246898e-06 -2.290512e-123 -1.636231e-123
#
#                z.1  Magnetometer: x  y.2  z.2       time   name
# 0     0.000000e+00                0    0    0   0.020000  mao.R
# 1     0.000000e+00                0    0    0   0.353333  mao.R
# 2     0.000000e+00                0    0    0   0.506895  mao.R
# 3     0.000000e+00                0    0    0   0.628720  mao.R
# 4     0.000000e+00                0    0    0   0.662872  mao.R
# ..             ...              ...  ...  ...        ...    ...
# 415  3.109628e-115                0    0    0  26.954340  mao.R
# 416  3.109628e-117                0    0    0  27.005450  mao.R
# 417  3.109628e-119                0    0    0  27.040880  mao.R
# 418  3.109628e-121                0    0    0  27.090130  mao.R
# 419  3.109628e-123                0    0    0  27.162060  mao.R
#
# [392 rows x 11 columns]
#       LinAccel: x         y         z      AngVel: x            y.1  \
# 0   -9.230152e-10  0.011857  0.007387   0.000000e+00   0.000000e+00
# 1    8.726553e-11 -0.001121 -0.000698   0.000000e+00   0.000000e+00
# 2   -3.256519e-11  0.000418  0.000261   0.000000e+00   0.000000e+00
# 3   -2.068602e-11  0.000266  0.000166   0.000000e+00   0.000000e+00
# 4   -9.023313e-10  0.011591  0.007222   0.000000e+00   0.000000e+00
# ..            ...       ...       ...            ...            ...
# 415 -1.980693e-12  0.000048 -0.000011 -1.985008e-114  7.418184e-116
# 416  2.771557e-11 -0.000666  0.000155 -1.985008e-116  7.418184e-118
# 417  7.773420e-11 -0.001868  0.000434 -1.985008e-118  7.418184e-120
# 418 -5.019906e-11  0.001206 -0.000280 -1.985008e-120  7.418184e-122
# 419 -2.872796e-11  0.000690 -0.000160 -1.985008e-122  7.418184e-124
#
#                z.1  Magnetometer: x  y.2  z.2       time  name
# 0     0.000000e+00                0    0    0   0.020000  pe.L
# 1     0.000000e+00                0    0    0   0.353333  pe.L
# 2     0.000000e+00                0    0    0   0.506895  pe.L
# 3     0.000000e+00                0    0    0   0.628720  pe.L
# 4     0.000000e+00                0    0    0   0.662872  pe.L
# ..             ...              ...  ...  ...        ...   ...
# 415  9.722186e-116                0    0    0  26.954340  pe.L
# 416  9.722186e-118                0    0    0  27.005450  pe.L
# 417  9.722186e-120                0    0    0  27.040880  pe.L
# 418  9.722186e-122                0    0    0  27.090130  pe.L
# 419  9.722186e-124                0    0    0  27.162060  pe.L
#
# [392 rows x 11 columns]
#       LinAccel: x         y         z      AngVel: x            y.1  \
# 0   -1.272218e-11  0.003385  0.000861   0.000000e+00   0.000000e+00
# 1    1.202806e-12 -0.000320 -0.000081   0.000000e+00   0.000000e+00
# 2   -4.488552e-13  0.000119  0.000030   0.000000e+00   0.000000e+00
# 3   -2.851213e-13  0.000076  0.000019   0.000000e+00   0.000000e+00
# 4   -1.243708e-11  0.003309  0.000842   0.000000e+00   0.000000e+00
# ..            ...       ...       ...            ...            ...
# 415 -1.727519e-05 -0.000075  0.000016  3.125226e-114  2.049070e-115
# 416  2.417285e-04  0.001056 -0.000230  3.125226e-116  2.049070e-117
# 417  6.779792e-04  0.002963 -0.000645  3.125226e-118  2.049070e-119
# 418 -4.378243e-04 -0.001913  0.000417  3.125226e-120  2.049070e-121
# 419 -2.505585e-04 -0.001095  0.000239  3.125226e-122  2.049070e-123
#
#                z.1  Magnetometer: x  y.2  z.2       time      name
# 0     0.000000e+00                0    0    0   0.020000  canela.R
# 1     0.000000e+00                0    0    0   0.353333  canela.R
# 2     0.000000e+00                0    0    0   0.506895  canela.R
# 3     0.000000e+00                0    0    0   0.628720  canela.R
# 4     0.000000e+00                0    0    0   0.662872  canela.R
# ..             ...              ...  ...  ...        ...       ...
# 415 -1.809183e-116                0    0    0  26.954340  canela.R
# 416 -1.809183e-118                0    0    0  27.005450  canela.R
# 417 -1.809183e-120                0    0    0  27.040880  canela.R
# 418 -1.809183e-122                0    0    0  27.090130  canela.R
# 419 -1.809183e-124                0    0    0  27.162060  canela.R
#
# [392 rows x 11 columns]
#       LinAccel: x         y         z      AngVel: x            y.1  \
# 0   -2.467355e-10  0.003492  0.000873   0.000000e+00   0.000000e+00
# 1    2.332736e-11 -0.000330 -0.000083   0.000000e+00   0.000000e+00
# 2   -8.705153e-12  0.000123  0.000031   0.000000e+00   0.000000e+00
# 3   -5.529678e-12  0.000078  0.000020   0.000000e+00   0.000000e+00
# 4   -2.412064e-10  0.003414  0.000854   0.000000e+00   0.000000e+00
# ..            ...       ...       ...            ...            ...
# 415  5.100909e-12 -0.000078  0.000002  6.673620e-116 -1.483127e-115
# 416 -7.137628e-11  0.001088 -0.000030  6.673620e-118 -1.483127e-117
# 417 -2.001900e-10  0.003051 -0.000085  6.673620e-120 -1.483127e-119
# 418  1.292783e-10 -0.001970  0.000055  6.673620e-122 -1.483127e-121
# 419  7.398353e-11 -0.001128  0.000031  6.673620e-124 -1.483127e-123
#
#                z.1  Magnetometer: x  y.2  z.2       time    name
# 0     0.000000e+00                0    0    0   0.020000  cabeca
# 1     0.000000e+00                0    0    0   0.353333  cabeca
# 2     0.000000e+00                0    0    0   0.506895  cabeca
# 3     0.000000e+00                0    0    0   0.628720  cabeca
# 4     0.000000e+00                0    0    0   0.662872  cabeca
# ..             ...              ...  ...  ...        ...     ...
# 415  8.580612e-117                0    0    0  26.954340  cabeca
# 416  8.580612e-119                0    0    0  27.005450  cabeca
# 417  8.580612e-121                0    0    0  27.040880  cabeca
# 418  8.580612e-123                0    0    0  27.090130  cabeca
# 419  8.580612e-125                0    0    0  27.162060  cabeca
#
# [392 rows x 11 columns]
#       LinAccel: x         y         z      AngVel: x            y.1  \
# 0   -2.390064e-10  0.003417  0.000721   0.000000e+00   0.000000e+00
# 1    2.259662e-11 -0.000323 -0.000068   0.000000e+00   0.000000e+00
# 2   -8.432459e-12  0.000121  0.000025   0.000000e+00   0.000000e+00
# 3   -5.356456e-12  0.000077  0.000016   0.000000e+00   0.000000e+00
# 4   -2.336504e-10  0.003341  0.000705   0.000000e+00   0.000000e+00
# ..            ...       ...       ...            ...            ...
# 415 -8.637594e-06 -0.000139 -0.000012  6.676278e-116 -1.488514e-115
# 416  1.208643e-04  0.001942  0.000163  6.676278e-118 -1.488514e-117
# 417  3.389896e-04  0.005447  0.000456  6.676278e-120 -1.488514e-119
# 418 -2.189121e-04 -0.003518 -0.000295  6.676278e-122 -1.488514e-121
# 419 -1.252792e-04 -0.002013 -0.000169  6.676278e-124 -1.488514e-123
#
#                z.1  Magnetometer: x  y.2  z.2       time    name
# 0     0.000000e+00                0    0    0   0.020000  pelvis
# 1     0.000000e+00                0    0    0   0.353333  pelvis
# 2     0.000000e+00                0    0    0   0.506895  pelvis
# 3     0.000000e+00                0    0    0   0.628720  pelvis
# 4     0.000000e+00                0    0    0   0.662872  pelvis
# ..             ...              ...  ...  ...        ...     ...
# 415  1.029610e-116                0    0    0  26.954340  pelvis
# 416  1.029610e-118                0    0    0  27.005450  pelvis
# 417  1.029610e-120                0    0    0  27.040880  pelvis
# 418  1.029610e-122                0    0    0  27.090130  pelvis
# 419  1.029610e-124                0    0    0  27.162060  pelvis
#
# [392 rows x 11 columns]
#      LinAccel: x         y         z      AngVel: x            y.1  \
# 0      -0.000695  0.003371  0.001436   0.000000e+00   0.000000e+00
# 1       0.000066 -0.000319 -0.000136   0.000000e+00   0.000000e+00
# 2      -0.000025  0.000119  0.000051   0.000000e+00   0.000000e+00
# 3      -0.000016  0.000076  0.000032   0.000000e+00   0.000000e+00
# 4      -0.000680  0.003296  0.001404   0.000000e+00   0.000000e+00
# ..           ...       ...       ...            ...            ...
# 415     0.000027 -0.000079 -0.000034 -4.992599e-115  2.110423e-115
# 416    -0.000380  0.001112  0.000475 -4.992599e-117  2.110423e-117
# 417    -0.001065  0.003119  0.001333 -4.992599e-119  2.110423e-119
# 418     0.000688 -0.002014 -0.000861 -4.992599e-121  2.110423e-121
# 419     0.000394 -0.001153 -0.000493 -4.992599e-123  2.110423e-123
#
#                z.1  Magnetometer: x  y.2  z.2       time         name
# 0     0.000000e+00                0    0    0   0.020000  clavicula.L
# 1     0.000000e+00                0    0    0   0.353333  clavicula.L
# 2     0.000000e+00                0    0    0   0.506895  clavicula.L
# 3     0.000000e+00                0    0    0   0.628720  clavicula.L
# 4     0.000000e+00                0    0    0   0.662872  clavicula.L
# ..             ...              ...  ...  ...        ...          ...
# 415  1.304890e-114                0    0    0  26.954340  clavicula.L
# 416  1.304890e-116                0    0    0  27.005450  clavicula.L
# 417  1.304890e-118                0    0    0  27.040880  clavicula.L
# 418  1.304890e-120                0    0    0  27.090130  clavicula.L
# 419  1.304890e-122                0    0    0  27.162060  clavicula.L
#
# [392 rows x 11 columns]
# Empty DataFrame
# Columns: [LinAccel: x, y, z, AngVel: x, y.1, z.1, Magnetometer: x, y.2, z.2, time, name]
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-243-f95760a6a93c> in <module>
#       5     df.to_csv(path_or_buf="./final_csv/{}".format(file), index=False)
#       6     print(df)
# ----> 7     df.plot(kind="scatter", x="time", y="y.1")
#       8     plt.title(file)
#       9     plt.show()
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     736         if kind in self._dataframe_kinds:
#     737             if isinstance(data, ABCDataFrame):
# --> 738                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     739             else:
#     740                 raise ValueError(
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59                 ax = plt.gca()
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      62     plot_obj.generate()
#      63     plot_obj.draw()
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in __init__(self, data, x, y, s, c, **kwargs)
#     928             # the handling of this argument later
#     929             s = 20
# --> 930         super().__init__(data, x, y, s=s, **kwargs)
#     931         if is_integer(c) and not self.data.columns.holds_integer():
#     932             c = self.data.columns[c]
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in __init__(self, data, x, y, **kwargs)
#     868             y = self.data.columns[y]
#     869         if len(self.data[x]._get_numeric_data()) == 0:
# --> 870             raise ValueError(self._kind + " requires x column to be numeric")
#     871         if len(self.data[y]._get_numeric_data()) == 0:
#     872             raise ValueError(self._kind + " requires y column to be numeric")
#
# ValueError: scatter requires x column to be numeric
