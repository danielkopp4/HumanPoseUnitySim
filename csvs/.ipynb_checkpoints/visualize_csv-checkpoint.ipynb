# %%
from os.path import isfile, join
import matplotlib.pyplot as plt
from os import listdir
import pandas as pd
import numpy as np
import os

# %%
files = [f for f in listdir(".") if isfile(join(".", f))]
files.remove("visualize_csv.ipynb")
files.remove('csvconvert.py')
files
# Out:
# ['mao.R.csv',
#  'pe.L.csv',
#  'canela.R.csv',
#  'cabeca.csv',
#  'pelvis.csv',
#  'clavicula.L.csv',
#  'femur.R.csv',
#  'pontape.L.csv',
#  'antebraco.L.csv',
#  'braco.R.csv',
#  'clavicula.R.csv',
#  'canela.L.csv',
#  'torax.csv',
#  'antebraco.R.csv',
#  'respiracao.csv',
#  'femur.L.csv',
#  'pe.R.csv',
#  'abdomen.csv',
#  'braco.L.csv',
#  'pontape.R.csv',
#  'pescoco.csv']

# %%
part = "pelvis" 
data = pd.read_csv("{}.csv".format(part))
data
# Out:
#     LinVel: x           y         z  AngVel: x          y.1           z.1  \
# 0   34.065170   28.894480 -9.240989   0.000043     0.000002  4.142596e-07
# 1    2.757611  106.455700  4.305785   0.021110     0.003845  1.226883e+01
# 2    2.027070   -0.400903 -0.022777  -0.087261     0.021512  1.122789e-03
# 3   -1.009866    0.249021  0.016026   0.092152     0.037383  2.246236e-03
# 4   -2.424277    0.357457 -0.027789  -0.063028  1402.832000 -6.503468e-06
# 5   -3.210566    0.329024 -0.004808  -0.025855     0.002031 -1.321501e-03
# 6    0.890573   -0.090359  0.020533   0.060002    -0.002552 -1.570731e-03
# 7    2.975741   -0.301320  0.016640   0.045663    -0.000326  6.240700e-04
# 8    1.787631   -0.353598 -0.011404   0.070095     0.029993  1.623620e-03
# 9    0.822834   -0.152489  0.003453  -0.014683    -0.029200 -4.184709e-03
# 10  -2.923588    0.324496 -0.032937  -0.070458  1411.087000  2.339196e-03
# 11  -1.930093    0.196205  0.010427   0.024694    -0.003396 -3.251634e-03
# 12   3.108748   -0.315649  0.029276   0.066717    -0.000956  3.546760e-04
# 13   1.569301   -0.204332 -0.005095   0.004344     0.003957  1.376201e-04
# 14   2.170787   -0.434631 -0.024469  -0.097319     0.030873  4.141164e-04
# 15  -0.732996    0.192957  0.017904   0.089497    -0.031027  1.482219e-03
# 16  -2.340434    0.372411 -0.019070  -0.050949     0.001296 -6.405857e-04
# 17  -3.266684    0.337649 -0.012123  -0.036137    -0.002539  1.649639e-04
# 18   0.315165   -0.031286  0.011398   0.055805    -0.002899 -2.064347e-03
# 19   3.291462   -0.334315  0.027386   0.054101    -0.000371  7.114620e-04
# 20   1.170663   -0.221638 -0.004053  -0.035069    -0.017483 -1.541315e-03
# 21  -1.727463    0.380692  0.010026   0.063751     0.041535  2.763838e-03
# 22  -2.757958    0.325372 -0.032889  -0.072549  1409.887000  7.610134e-04
# 23  -2.411882    0.244612  0.013935   0.012420    -0.003017 -3.105899e-03
# 24   2.699042   -0.273795  0.026648   0.067051    -0.001298 -2.235044e-05
# 25   1.811722   -0.210561 -0.005316   0.027276     0.002645  1.085778e-03
# 26   2.249438   -0.446983 -0.024678   0.108747     0.042641  3.114504e-03
# 27  -0.309516    0.096855  0.018580   0.067110    -0.043656 -2.809152e-03
# 28  -2.244363    0.394537 -0.004909  -0.025447     0.023128 -2.494357e-03
# 29  -3.231129    0.339791 -0.023817  -0.050640  1430.818000  3.343167e-03
#
#          time    name
# 0    0.539279  pelvis
# 1    1.052474  pelvis
# 2    1.555731  pelvis
# 3    2.057780  pelvis
# 4    2.571023  pelvis
# 5    3.071494  pelvis
# 6    3.577557  pelvis
# 7    4.089488  pelvis
# 8    4.597568  pelvis
# 9    5.106799  pelvis
# 10   6.132798  pelvis
# 11   6.641951  pelvis
# 12   7.150146  pelvis
# 13   7.662948  pelvis
# 14   8.171892  pelvis
# 15   8.672464  pelvis
# 16   9.184596  pelvis
# 17   9.690443  pelvis
# 18  10.191920  pelvis
# 19  10.701280  pelvis
# 20  11.717030  pelvis
# 21  12.222530  pelvis
# 22  12.733190  pelvis
# 23  13.249200  pelvis
# 24  13.761230  pelvis
# 25  14.265830  pelvis
# 26  14.766470  pelvis
# 27  15.272140  pelvis
# 28  15.772230  pelvis
# 29  16.275430  pelvis

# %%
def drop(data, sort, percent=0.07, by_axis=False):
    to_drop = []
    i = 0
    while i < len(sort) * percent:
        to_drop.append(sort[i][0])
        i += 1
    
    return data.drop(to_drop)

def filter_data(data, key, percent=0.2, by_axis=False):
    if by_axis:
        y = data.iloc[:,key]
    else:
        y = data[key]
        
    x = range(len(y))
    xy = list(zip(x, y))
    sort = sorted(xy, key=lambda tup: tup[1], reverse=True)
    data = drop(data, sort)
    data.reset_index(drop=True)
     if by_axis:
        y = data.iloc[:,key]
    else:
        y = data[key]
        
    x = range(len(y))
    xy = list(zip(x, y))
    sort = sorted(xy, key=lambda tup: tup[1], reverse=True)
    
    i = 0
    while i < len(y) * percent:
        row = sort[i][0]
        if (row == len(xy) - 1):
            data.iloc[row, axis] = data.iloc[row - 1, axis]
        elif (row == 0):
            data.iloc[row, axis] = data.iloc[row + 1, axis]
        else:    
            data.iloc[row, axis] = 0.5 * (data.iloc[row - 1, axis] + data.iloc[row + 1, axis])
        i += 1
        
    return data

# %%
def integrate(xy):
    integrals = []
    integrals.append(xy[0][1] * xy[0][0])
    i = -1
    for element in xy:
        if i == -1:
            i += 1
            continue
        
        deltatime = element[0] - xy[i][0]
        integrals.append(element[1] * (deltatime) + integrals[i])
        i += 1
    return integrals

# %%
data = filter_data(data, "y.1")
# Out:
# [(3, 0.03738344), (12, 0.03087262), (7, 0.0299927), (23, 0.02312811), (2, 0.02151176), (11, 0.003957362), (1, 0.003844942), (21, 0.0026447109999999997), (4, 0.002030764), (14, 0.00129557), (0, 2.01642e-06), (6, -0.0003258345), (17, -0.0003709621), (10, -0.0009563785000000001), (20, -0.0012981639999999999), (15, -0.002538616), (5, -0.002551528), (16, -0.0028993129999999997), (19, -0.0030172790000000003), (9, -0.0033959859999999997), (18, -0.01748269), (8, -0.02920028), (13, -0.03102691), (22, -0.04365551)]
# [(7, 0.0299927), (23, 0.02312811), (2, 0.02151176), (11, 0.003957362), (1, 0.003844942), (21, 0.0026447109999999997), (4, 0.002030764), (14, 0.00129557), (0, 2.01642e-06), (6, -0.0003258345), (17, -0.0003709621), (10, -0.0009563785000000001), (20, -0.0012981639999999999), (15, -0.002538616), (5, -0.002551528), (16, -0.0028993129999999997), (19, -0.0030172790000000003), (9, -0.0033959859999999997), (18, -0.01748269), (8, -0.02920028), (13, -0.03102691), (22, -0.04365551)]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-692dc1b2be9f> in <module>
# ----> 1 data = filter_data(data, "y.1")
#
# <ipython-input-75-ddbc028b49b5> in filter_data(data, key, percent, by_axis)
#      31             data.iloc[row, axis] = data.iloc[row + 1, axis]
#      32         else:
# ---> 33             data.iloc[row, axis] = 0.5 * (data.iloc[row - 1, axis] + data.iloc[row + 1, axis])
#      34         i += 1
#      35
#
# AttributeError: 'tuple' object has no attribute 'iloc'

# %%
zipped = list(zip(data["time"], data["y.1"]))

plt.plot(data["time"], integrate(zipped), 'ro')
plt.title("{} angle".format(part))
plt.show()

# %%
data.plot(kind="scatter", x="time", y="y.1", color="red")
plt.title("{} angular velocity".format(part))
plt.show()

# %%
for file in files:
    df = pd.read_csv(file)
    for axis in range(6):
        df = filter_data(df, axis, by_axis=True)
    df.to_csv(path_or_buf="./final_csv/{}".format(file), index=False)
    print(df)
    df.plot(kind="scatter", x="time", y="y.1")
    plt.title(file)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-f95760a6a93c> in <module>
#       2     df = pd.read_csv(file)
#       3     for axis in range(6):
# ----> 4         df = filter_data(df, axis, by_axis=True)
#       5     df.to_csv(path_or_buf="./final_csv/{}".format(file), index=False)
#       6     print(df)
#
# <ipython-input-71-44b2112c91d1> in filter_data(data, key, percent, by_axis)
#      23         row = sort[i][0]
#      24         if (row == len(xy) - 1):
# ---> 25             data.iloc[row, axis] = data.iloc[row - 1, axis]
#      26         elif (row == 0):
#      27             data.iloc[row, axis] = data.iloc[row + 1, axis]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1402                 except (KeyError, IndexError, AttributeError):
#    1403                     pass
# -> 1404             return self._getitem_tuple(key)
#    1405         else:
#    1406             # we by definition only have the 0th axis
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2065     def _getitem_tuple(self, tup):
#    2066
# -> 2067         self._has_valid_tuple(tup)
#    2068         try:
#    2069             return self._getitem_lowerdim(tup)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     230                 raise IndexingError("Too many indexers")
#     231             try:
# --> 232                 self._validate_key(k, i)
#     233             except ValueError:
#     234                 raise ValueError(
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1987             return
#    1988         elif is_integer(key):
# -> 1989             self._validate_integer(key, axis)
#    1990         elif isinstance(key, tuple):
#    1991             # a tuple should already have been caught by this point
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2061         len_axis = len(self.obj._get_axis(axis))
#    2062         if key >= len_axis or key < -len_axis:
# -> 2063             raise IndexError("single positional indexer is out-of-bounds")
#    2064
#    2065     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds
